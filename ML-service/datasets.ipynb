# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train_df = pd.read_csv("favorita-grocery-sales-forecasting/train.csv")
test_df = pd.read_csv("favorita-grocery-sales-forecasting/test.csv")
holidays_events_df = pd.read_csv("favorita-grocery-sales-forecasting/holidays_events.csv")
items_df = pd.read_csv("favorita-grocery-sales-forecasting/items.csv")
oil_df = pd.read_csv("favorita-grocery-sales-forecasting/oil.csv")
stores_df = pd.read_csv("favorita-grocery-sales-forecasting/stores.csv")
transactions_df = pd.read_csv("favorita-grocery-sales-forecasting/transactions.csv")
# Out:
# /var/folders/5l/17wd4myj387b056cpgkkpxth0000gn/T/ipykernel_4551/3825871546.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv("favorita-grocery-sales-forecasting/train.csv")

# %%
train_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125497040 entries, 0 to 125497039
# Data columns (total 6 columns):
#  #   Column       Non-Null Count      Dtype
# ---  ------       --------------      -----
#  0   id           125497040 non-null  int64
#  1   date         125497040 non-null  object
#  2   store_nbr    125497040 non-null  int64
#  3   item_nbr     125497040 non-null  int64
#  4   unit_sales   125497040 non-null  float64
#  5   onpromotion  103839389 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.6+ GB

# %%
holidays_events_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
items_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_nbr    4100 non-null   int64
#  1   family      4100 non-null   object
#  2   class       4100 non-null   int64
#  3   perishable  4100 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 128.3+ KB

# %%
oil_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
stores_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
transactions_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# Merging

# %%
df = train_df.copy()

# %%
df = df.merge(items_df, on='item_nbr', how='left')
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion        family  \
# 0   0  2013-01-01         25    103665         7.0         NaN  BREAD/BAKERY
# 1   1  2013-01-01         25    105574         1.0         NaN     GROCERY I
# 2   2  2013-01-01         25    105575         2.0         NaN     GROCERY I
# 3   3  2013-01-01         25    108079         1.0         NaN     GROCERY I
# 4   4  2013-01-01         25    108701         1.0         NaN          DELI
#
#    class  perishable
# 0   2712           1
# 1   1045           0
# 2   1045           0
# 3   1030           0
# 4   2644           1

# %%
df = df.merge(stores_df, on='store_nbr', how='left')
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion        family  \
# 0   0  2013-01-01         25    103665         7.0         NaN  BREAD/BAKERY
# 1   1  2013-01-01         25    105574         1.0         NaN     GROCERY I
# 2   2  2013-01-01         25    105575         2.0         NaN     GROCERY I
# 3   3  2013-01-01         25    108079         1.0         NaN     GROCERY I
# 4   4  2013-01-01         25    108701         1.0         NaN          DELI
#
#    class  perishable     city        state type  cluster
# 0   2712           1  Salinas  Santa Elena    D        1
# 1   1045           0  Salinas  Santa Elena    D        1
# 2   1045           0  Salinas  Santa Elena    D        1
# 3   1030           0  Salinas  Santa Elena    D        1
# 4   2644           1  Salinas  Santa Elena    D        1

# %%
df = df.merge(oil_df, on="date", how="left")
df["dcoilwtico"] = df["dcoilwtico"].ffill()
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion        family  \
# 0   0  2013-01-01         25    103665         7.0         NaN  BREAD/BAKERY
# 1   1  2013-01-01         25    105574         1.0         NaN     GROCERY I
# 2   2  2013-01-01         25    105575         2.0         NaN     GROCERY I
# 3   3  2013-01-01         25    108079         1.0         NaN     GROCERY I
# 4   4  2013-01-01         25    108701         1.0         NaN          DELI
#
#    class  perishable     city        state type  cluster  dcoilwtico
# 0   2712           1  Salinas  Santa Elena    D        1         NaN
# 1   1045           0  Salinas  Santa Elena    D        1         NaN
# 2   1045           0  Salinas  Santa Elena    D        1         NaN
# 3   1030           0  Salinas  Santa Elena    D        1         NaN
# 4   2644           1  Salinas  Santa Elena    D        1         NaN

# %%
df = df.merge(transactions_df, on=["date", "store_nbr"], how="left")
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion        family  \
# 0   0  2013-01-01         25    103665         7.0         NaN  BREAD/BAKERY
# 1   1  2013-01-01         25    105574         1.0         NaN     GROCERY I
# 2   2  2013-01-01         25    105575         2.0         NaN     GROCERY I
# 3   3  2013-01-01         25    108079         1.0         NaN     GROCERY I
# 4   4  2013-01-01         25    108701         1.0         NaN          DELI
#
#    class  perishable     city        state type  cluster  dcoilwtico  \
# 0   2712           1  Salinas  Santa Elena    D        1         NaN
# 1   1045           0  Salinas  Santa Elena    D        1         NaN
# 2   1045           0  Salinas  Santa Elena    D        1         NaN
# 3   1030           0  Salinas  Santa Elena    D        1         NaN
# 4   2644           1  Salinas  Santa Elena    D        1         NaN
#
#    transactions
# 0         770.0
# 1         770.0
# 2         770.0
# 3         770.0
# ...

# %%
holidays_events_df
# Out:
#            date        type    locale locale_name  \
# 0    2012-03-02     Holiday     Local       Manta
# 1    2012-04-01     Holiday  Regional    Cotopaxi
# 2    2012-04-12     Holiday     Local      Cuenca
# 3    2012-04-14     Holiday     Local    Libertad
# 4    2012-04-21     Holiday     Local    Riobamba
# ..          ...         ...       ...         ...
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# ..                             ...          ...
# ...

# %%
holidays_events_df = holidays_events_df[holidays_events_df['transferred'] == False]
holidays_events_df
# Out:
#            date        type    locale locale_name  \
# 0    2012-03-02     Holiday     Local       Manta
# 1    2012-04-01     Holiday  Regional    Cotopaxi
# 2    2012-04-12     Holiday     Local      Cuenca
# 3    2012-04-14     Holiday     Local    Libertad
# 4    2012-04-21     Holiday     Local    Riobamba
# ..          ...         ...       ...         ...
# 345  2017-12-22  Additional  National     Ecuador
# 346  2017-12-23  Additional  National     Ecuador
# 347  2017-12-24  Additional  National     Ecuador
# 348  2017-12-25     Holiday  National     Ecuador
# 349  2017-12-26  Additional  National     Ecuador
#
#                        description  transferred
# 0               Fundacion de Manta        False
# 1    Provincializacion de Cotopaxi        False
# 2              Fundacion de Cuenca        False
# 3        Cantonizacion de Libertad        False
# 4        Cantonizacion de Riobamba        False
# ..                             ...          ...
# ...

# %%
holidays_events_df = holidays_events_df.groupby("date").agg({
    "type": "first",
    "locale": "first"
}).reset_index()
holidays_events_df["is_holiday"] = 1
holidays_events_df
# Out:
#            date        type    locale  is_holiday
# 0    2012-03-02     Holiday     Local           1
# 1    2012-04-01     Holiday  Regional           1
# 2    2012-04-12     Holiday     Local           1
# 3    2012-04-14     Holiday     Local           1
# 4    2012-04-21     Holiday     Local           1
# ..          ...         ...       ...         ...
# 295  2017-12-22     Holiday     Local           1
# 296  2017-12-23  Additional  National           1
# 297  2017-12-24  Additional  National           1
# 298  2017-12-25     Holiday  National           1
# 299  2017-12-26  Additional  National           1
#
# [300 rows x 4 columns]

# %%
df = df.merge(holidays_events_df[["date", "is_holiday"]], on='date', how='left')
df["is_holiday"] = df["is_holiday"].fillna(0)
df.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion        family  \
# 0   0  2013-01-01         25    103665         7.0         NaN  BREAD/BAKERY
# 1   1  2013-01-01         25    105574         1.0         NaN     GROCERY I
# 2   2  2013-01-01         25    105575         2.0         NaN     GROCERY I
# 3   3  2013-01-01         25    108079         1.0         NaN     GROCERY I
# 4   4  2013-01-01         25    108701         1.0         NaN          DELI
#
#    class  perishable     city        state type  cluster  dcoilwtico  \
# 0   2712           1  Salinas  Santa Elena    D        1         NaN
# 1   1045           0  Salinas  Santa Elena    D        1         NaN
# 2   1045           0  Salinas  Santa Elena    D        1         NaN
# 3   1030           0  Salinas  Santa Elena    D        1         NaN
# 4   2644           1  Salinas  Santa Elena    D        1         NaN
#
#    transactions  is_holiday
# 0         770.0         1.0
# 1         770.0         1.0
# ...

# %%
df.to_csv('favorita_sales.csv', index=False)

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125497040 entries, 0 to 125497039
# Data columns (total 16 columns):
#  #   Column        Non-Null Count      Dtype
# ---  ------        --------------      -----
#  0   id            125497040 non-null  int64
#  1   date          125497040 non-null  object
#  2   store_nbr     125497040 non-null  int64
#  3   item_nbr      125497040 non-null  int64
#  4   unit_sales    125497040 non-null  float64
#  5   onpromotion   103839389 non-null  object
#  6   family        125497040 non-null  object
#  7   class         125497040 non-null  int64
#  8   perishable    125497040 non-null  int64
#  9   city          125497040 non-null  object
#  10  state         125497040 non-null  object
#  11  type          125497040 non-null  object
#  12  cluster       125497040 non-null  int64
#  13  dcoilwtico    125496462 non-null  float64
#  14  transactions  125282415 non-null  float64
#  15  is_holiday    125497040 non-null  float64
# ...
